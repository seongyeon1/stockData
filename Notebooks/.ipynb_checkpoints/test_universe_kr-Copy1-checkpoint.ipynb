# %%
import os
os.chdir('/Users/seongyeon-kim/Desktop/Dinger')

# %% [markdown]
# ### 프로젝트 root로 설정

# %%
import warnings
warnings.filterwarnings('ignore')

print("현재 디렉토리 " , os.getcwd())

from tqdm import tqdm
import pandas as pd 

from Dinger import universe_module as um
# Out:
# 현재 디렉토리  /Users/seongyeon-kim/Desktop/Dinger

# %%
import numpy as np

# %%
data = pd.read_csv('./data/stock_kr.csv')

# %%
data = um.Universe(data)

# %%
data.get_standard_df()
# Out:
#                   MKT_VAL        PER       PBR       DIV           매출액  \
# SEC_NM_KOR
# IT          791627.557377  30.229590  2.360836  0.732951   2878.657895
# 건강관리        379416.789298  29.659097  4.394548  0.548194    531.131488
# 경기관련소비재     376036.335211  20.016451  1.509211  1.401099   4230.656338
# 금융          693963.971429   4.575571  0.470429  2.430429  25240.130952
# 산업재         397119.858357  42.648584  1.739122  1.447479   5455.050992
# 소재          461972.765217  16.407696  1.454826  1.640217   4459.973913
# 에너지         640968.459459  25.066757  1.930000  1.471351  16468.756757
# 유틸리티        669974.588235  34.691765  1.293529  2.681765  18977.235294
# 커뮤니케이션서비스   948847.473684  27.989211  2.277632  0.758509   2445.026316
# 필수소비재       273107.592233  19.430680  1.387864  1.585922   3764.941748
#
#                    영업이익        당기순이익       ROA          ROE        베타
# SEC_NM_KOR
# IT           391.440199   298.204319  2.647245     3.790985  1.008083
# 건강관리          47.105085    42.718644 -1.927517 -1379.627517  0.962050
# 경기관련소비재      267.667614   255.566952  1.603390     1.901977  0.879725
# 금융          1501.511364  1207.558140  1.116535     5.943307  0.541356
# 산업재          419.566572   313.157143  3.062678     2.823932  0.897877
# 소재           374.868421   305.118943  6.362609    10.500435  0.867022
# 에너지         1935.648649  1259.027027  1.536111     2.755556  0.799710
# 유틸리티       -3598.529412 -2754.823529  3.247059     5.852941  0.392353
# 커뮤니케이션서비스    232.646018   134.596491  0.536842    -0.780702  0.936200
# 필수소비재        260.450000   177.689320  2.388350     3.788350  0.734272

# %%
data.get_score()
# Out:
#            종목명 SEC_NM_KOR     업종명    시장구분  Score
# 종목코드
# 5380       현대차    경기관련소비재    운수장비   KOSPI    8.0
# 270         기아    경기관련소비재    운수장비   KOSPI    8.0
# 12330    현대모비스    경기관련소비재    운수장비   KOSPI    8.0
# 51900   LG생활건강    경기관련소비재      화학   KOSPI    8.0
# 90430   아모레퍼시픽    경기관련소비재      화학   KOSPI    6.0
# ...        ...        ...     ...     ...    ...
# 33200      모아텍         IT    IT부품  KOSDAQ    1.0
# 9140      경인전자         IT    전기전자   KOSPI    4.0
# 17250      인터엠         IT  일반전기전자  KOSDAQ    0.0
# 32960     동일기연         IT    IT부품  KOSDAQ    3.0
# 321260    프로이천         IT  일반전기전자  KOSDAQ    3.0
#
# [2138 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('./data/stock_kr.csv')

# %%
if '종목코드' in data.columns:
    data.set_index('종목코드', inplace=True)

data.dropna(inplace=True)

gubun = data[['종목명','SEC_NM_KOR','업종명','시장구분']]
sector_list = data.SEC_NM_KOR.unique()

# %%
scaler = StandardScaler()
data.drop(gubun.columns.tolist(), axis=1, inplace=True)
data.drop('ALL_MKT_VAL', axis=1, inplace=True)
scaled_data = scaler.fit_transform(data)

# %%
data.columns
# Out:
# Index(['MKT_VAL', 'PER', 'PBR', 'DIV', '매출액', '영업이익', '당기순이익', 'ROA', 'ROE',
#        '베타'],
#       dtype='object')

# %%
scaled_data = pd.DataFrame(scaled_data, columns=data.columns).set_index(data.index)

# %%
scaled_data = gubun.merge(scaled_data, right_index=True, left_index=True)

# %% [markdown]
# ### 스케일링 후

# %%
scaled_data.describe().T
# Out:
#           count          mean       std        min       25%       50%  \
# MKT_VAL  2138.0 -1.778538e-17  1.000234  -0.095551 -0.088563 -0.082387
# PER      2138.0  3.554479e-17  1.000234  -0.125980 -0.125980 -0.089228
# PBR      2138.0 -6.885018e-17  1.000234  -0.389764 -0.260518 -0.162660
# DIV      2138.0 -7.963176e-16  1.000234  -0.656429 -0.656429 -0.435159
# 매출액      2138.0 -1.818782e-17  1.000234  -0.179651 -0.173552 -0.163495
# 영업이익     2138.0  1.529672e-16  1.000234 -16.718601 -0.092908 -0.086657
# 당기순이익    2138.0  1.228749e-17  1.000234 -15.819584 -0.092933 -0.084151
# ROA      2138.0  3.479183e-17  1.000234  -8.330413 -0.258735  0.078925
# ROE      2138.0 -6.213523e-18  1.000234 -46.227466  0.021100  0.022001
# 베타       2138.0  6.792197e-17  1.000234  -3.610337 -0.654906  0.024843
#
#               75%        max
# MKT_VAL -0.064998  43.195627
# PER     -0.045591  40.747997
# PBR      0.023824  36.635615
# DIV      0.334020  11.861166
# 매출액     -0.124845  29.204609
# 영업이익    -0.067903  35.876610
# 당기순이익   -0.063742  36.008239
# ROA      0.424624   8.021971
# ROE      0.022802   0.038234
# 베타       0.615929   8.300048

# %% [markdown]
# ### 스케일링 전

# %%
data.describe().T
# Out:
#           count           mean           std        min        25%       50%  \
# MKT_VAL  2138.0  578216.255379  6.041336e+06    1096.00  43302.250  80606.00
# PER      2138.0      27.354181  2.171816e+02       0.00      0.000      7.98
# PBR      2138.0       2.110968  5.417282e+00       0.00      0.700      1.23
# DIV      2138.0       1.245987  1.898572e+00       0.00      0.000      0.42
# 매출액      2138.0    4704.222170  2.628049e+04     -16.00    144.250    408.50
# 영업이익     2138.0     361.128157  3.920152e+03  -65163.00     -3.000     21.50
# 당기순이익    2138.0     279.725444  3.075246e+03  -48358.00     -6.000     21.00
# ROA      2138.0       2.318288  1.244146e+01    -101.30     -0.900      3.30
# ROE      2138.0    -188.490271  8.860490e+03 -409690.70     -1.575      6.40
# 베타       2138.0       0.911594  3.384393e-01      -0.31      0.690      0.92
#
#                 75%           max
# MKT_VAL  185631.250  2.614765e+08
# PER          17.455  8.875000e+03
# PBR           2.240  2.005300e+02
# DIV           1.880  2.376000e+01
# 매출액        1424.000  7.720360e+05
# 영업이익         95.000  1.409700e+05
# 당기순이익        83.750  1.109880e+05
# ROA           7.600  1.021000e+02
# ROE          13.500  1.502000e+02
# 베타            1.120  3.720000e+00

# %%
data.get_score(mode='std')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 data.get_score(mode='std')
#
# File ~/Desktop/Dinger/Dinger/universe_module.py:74, in Universe.get_score(self, mode)
#      72 data.drop('ALL_MKT_VAL', axis=1, inplace=True)
#      73 scaled_data = scaler.fit_transform(data)
# ---> 74 return gubun.merge(scaled_data, right_index=True, left_index=True)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
#    9354         sort=sort,
#    9355         suffixes=suffixes,
#    9356         copy=copy,
#    9357         indicator=indicator,
#    9358         validate=validate,
#    9359     )
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:629, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     611 def __init__(
#     612     self,
#     613     left: DataFrame | Series,
#    (...)
#     626     validate: str | None = None,
#     627 ):
#     628     _left = _validate_operand(left)
# --> 629     _right = _validate_operand(right)
#     630     self.left = self.orig_left = _left
#     631     self.right = self.orig_right = _right
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:2281, in _validate_operand(obj)
#    2279         return obj.to_frame()
#    2280 else:
# -> 2281     raise TypeError(
#    2282         f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2283     )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'numpy.ndarray'> was passed
