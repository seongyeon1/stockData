# %%
import os
os.chdir('/Users/mac/Desktop/Dinger')

# %% [markdown]
# ### 프로젝트 root로 설정

# %%
print("현재 디렉토리 " , os.getcwd())
# Out:
# 현재 디렉토리  /Users/mac/Desktop/Dinger

# %%
import pandas as pd 

data = pd.read_csv("/Users/mac/Desktop/Dinger/ExampleStocks/005930")[["Close", "Volume"]]

# %%
from Dinger import resnet

# %%
gd = resnet.GenerateDataset(data)
image_data, t_data = gd.generate_image()
# Out:
# Done Scaling
# Max Close : 91000.0, Min Close: 638.0
# Max Volume : 90306177.0, Min Volume: 0.0

# %%
import matplotlib.pyplot as plt

plt.imshow(image_data[-1], cmap="gray")
plt.show()
